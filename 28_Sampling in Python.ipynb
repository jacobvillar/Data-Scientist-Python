# %% [markdown]
# # 1. Introduction to Sampling
#
# Sampling and point estimates
#
# Estimating the population of France
#
# ![image.png](attachment:image.png)
#
# Sampling households
#
# ![image-3.png](attachment:image-3.png)
#
# Population vs. sample
#
# ![image-4.png](attachment:image-4.png)
#
# Coffee rating dataset
#
# ![image-6.png](attachment:image-6.png)
#
# Points vs. flavor: population
#
# ![image-7.png](attachment:image-7.png)
#
# Points vs. flavor: 10 row sample
#
# ![image-8.png](attachment:image-8.png)
#
# Python sampling for Series
#
# ![image-9.png](attachment:image-9.png)
#
# Population parameters & point estimates
#
# ![image-10.png](attachment:image-10.png)
#
# Point estimates with pandas
#
# ![image-11.png](attachment:image-11.png)

# %% [markdown]
# ### Reasons for sampling
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Simple sampling with pandas
#
# ![image.png](attachment:image.png)

# %%
'''
# Sample 1000 rows from spotify_population
spotify_sample = spotify_population.sample(n=1000)

# Print the sample
print(spotify_sample)

# Calculate the mean duration in mins from spotify_population
mean_dur_pop = spotify_population['duration_minutes'].mean()

# Calculate the mean duration in mins from spotify_sample
mean_dur_samp =  spotify_sample['duration_minutes'].mean()

# Print the means
print(mean_dur_pop)
print(mean_dur_samp)


'''
# Out:
# "\n# Sample 1000 rows from spotify_population\nspotify_sample = spotify_population.sample(n=1000)\n\n# Print the sample\nprint(spotify_sample)\n\n# Calculate the mean duration in mins from spotify_population\nmean_dur_pop = spotify_population['duration_minutes'].mean()\n\n# Calculate the mean duration in mins from spotify_sample\nmean_dur_samp =  spotify_sample['duration_minutes'].mean()\n\n# Print the means\nprint(mean_dur_pop)\nprint(mean_dur_samp)\n\n\n"

# %% [markdown]
# Powerful point estimating! Notice that the mean song duration in the sample is similar, but not identical to the mean song duration in the whole population.

# %% [markdown]
# ### Simple sampling and calculating with NumPy
#
# ![image-2.png](attachment:image-2.png)

# %%
'''
# Create a pandas Series from the loudness column of spotify_population
loudness_pop = spotify_population['loudness']

# Sample 100 values of loudness_pop
loudness_samp = loudness_pop.sample(n=100)

# Calculate the mean of loudness_pop
mean_loudness_pop = np.mean(loudness_pop)

# Calculate the mean of loudness_samp
mean_loudness_samp = np.mean(loudness_samp)

# Print the means
print(mean_loudness_pop)
print(mean_loudness_samp)

'''
# Out:
# "\n# Create a pandas Series from the loudness column of spotify_population\nloudness_pop = spotify_population['loudness']\n\n# Sample 100 values of loudness_pop\nloudness_samp = loudness_pop.sample(n=100)\n\n# Calculate the mean of loudness_pop\nmean_loudness_pop = np.mean(loudness_pop)\n\n# Calculate the mean of loudness_samp\nmean_loudness_samp = np.mean(loudness_samp)\n\n# Print the means\nprint(mean_loudness_pop)\nprint(mean_loudness_samp)\n\n"

# %% [markdown]
# ## 1.1 Convenience Sampling
#
# 1. Convenience sampling
#
#     The point estimates you calculated in the previous exercises were very close to the population parameters that they were based on, but is this always the case?
#
# 2. The Literary Digest election prediction
#
# ![image-2.png](attachment:image-2.png)
#
# 3. Finding the mean age of French people
#
# ![image-3.png](attachment:image-3.png)
#
# 4. How accurate was the survey?
#
# ![image-4.png](attachment:image-4.png)
#
# 5. Convenience sampling coffee ratings
#
# ![image-5.png](attachment:image-5.png)
#
# 6. Visualizing selection bias
#
# ![image-6.png](attachment:image-6.png)
#
# 7. Distribution of a population and of a convenience sample
#
# ![image-7.png](attachment:image-7.png)
#
# 8. Visualizing selection bias for a random sample
#
# ![image-8.png](attachment:image-8.png)
#
# ![image-9.png](attachment:image-9.png)

# %% [markdown]
# ### Are findings from the sample generalizable?
#
# ![image.png](attachment:image.png)

# %%
'''
# Visualize the distribution of acousticness with a histogram
spotify_population["acousticness"].hist(bins = np.arange(0,1.01,0.01))
plt.show()

'''
# Out:
# '\n# Visualize the distribution of acousticness with a histogram\nspotify_population["acousticness"].hist(bins = np.arange(0,1.01,0.01))\nplt.show()\n\n'

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Convenience
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Ace acouticness analysis! The acousticness values in the sample are all greater than 0.95, whereas they range from 0 to 1 in the whole population.

# %% [markdown]
# ### 1.3 Pseudo-random number generation
#
# True random numbers
#
# ![image.png](attachment:image.png)
#
# Pseudo-random number generation
#
# ![image-2.png](attachment:image-2.png)
#
# Pseudo-random number generation example
#
# ![image-3.png](attachment:image-3.png)
#
# Random number generating functions
#
# ![image-4.png](attachment:image-4.png)
#
# Visualizing random numbers
#
# ![image-5.png](attachment:image-5.png)
#
#     - The first arguments to each random number function specify distribution parameters
#     - size: how many numbers
#     - beta distribution, and its parameters are named a and b. These random numbers come from a continuous distribution, so a great way to visualize them is with a histogram.
#
# Random numbers seeds
#
# ![image-6.png](attachment:image-6.png)
#
#     - The loc and scale arguments set the mean and standard deviation of the distribution, and the size argument determines how many random numbers from that distribution will be returned.

# %% [markdown]
# ## Generating random numbers
#
# ![image.png](attachment:image.png)

# %%
'''

# Generate random numbers from a Uniform(-3, 3)
uniforms = np.random.uniform(low=-3, high=3, size=5000)

# Plot a histogram of uniform values, binwidth 0.25
plt.hist(uniforms, bins = np.arange(-3,3.25,0.25))
plt.show()

-----------------------------------------------------

# Generate random numbers from a Normal(5, 2)
normals = np.random.normal(loc=5, scale=2, size=5000)

# Plot a histogram of normal values, binwidth 0.5
plt.hist(normals, bins = np.arange(-2,13.5,0.5))
plt.show()

'''
# Out:
# '\n\n# Generate random numbers from a Uniform(-3, 3)\nuniforms = np.random.uniform(low=-3, high=3, size=5000)\n\n# Plot a histogram of uniform values, binwidth 0.25\nplt.hist(uniforms, bins = np.arange(-3,3.25,0.25))\nplt.show()\n\n-----------------------------------------------------\n\n# Generate random numbers from a Normal(5, 2)\nnormals = np.random.normal(loc=5, scale=2, size=5000)\n\n# Plot a histogram of normal values, binwidth 0.5\nplt.hist(normals, bins = np.arange(-2,13.5,0.5))\nplt.show()\n\n'

# %% [markdown]
# #### Uniform
#
# ![image-2.png](attachment:image-2.png)
#
# #### Normal
#
# ![image.png](attachment:image.png)
#
# Notice how the histograms almost take the flat and bell curve shapes of the uniform and normal distributions, but there is a bit of random noise.

# %% [markdown]
# ### Understanding random seeds
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# # 2. Sampling Methods
#
# Simple random sampling
#
#     - Each coffee has the same chance as any other of being picked. When using this technique, sometimes we might end up with two coffees that were next to each other in the dataset, and sometimes we might end up with large areas of the dataset that were not selected from at all.
#
# Simple random sampling with pandas
#
# ![image.png](attachment:image.png)
#
# Systematic sampling
#
#     - samples the population at regular intervals.
#
# Systematic sampling - defining the interval
